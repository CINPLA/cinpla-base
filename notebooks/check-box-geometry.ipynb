# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import spatial_maps as sp
import expipe
import os
import sys
import pathlib
import numpy as np
import numpy.ma as ma
import scipy
import tqdm
import pandas as pd

sys.path.append('../ca2-mec') if '../ca2-mec' not in sys.path else None 
import dataloader as dl
from utils import *

# %%
project = expipe.get_project(dl.project_path())
project.actions

# %%
lim = None # limit recording times - in seconds
include_actions = ['BL-081021-1', 'TL-081021-1', 'TR-081021-1', 'BR-081021-1'] # choose actions to inspect
tracking = {action_id : dl.load_tracking(action_id, lim=lim) for action_id in include_actions}

# %%
fig,axs = plt.subplots(ncols=len(tracking),figsize=(4*5,5))
for ax,action_id in zip(axs,tracking):
    x,y,t,_ = tracking[action_id].T
    y = 1-y
    ax.scatter(x,y,s=0.1)
    ax.set_title(action_id)
